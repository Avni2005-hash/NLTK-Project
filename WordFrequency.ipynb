# %% [markdown]
# <a href="https://colab.research.google.com/github/Avni2005-hash/NLTK-Project/blob/main/WordFrequency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.probability import FreqDist
import matplotlib.pyplot as plt
nltk.download('punkt')
nltk.download('punkt_tab')
text="Natural Language Processing helps computers understand human language. Applications include chatbots, translation, and sentiment analysis."
words=nltk.word_tokenize(text.lower())
print(words)
# Out:
# ['natural', 'language', 'processing', 'helps', 'computers', 'understand', 'human', 'language', '.', 'applications', 'include', 'chatbots', ',', 'translation', ',', 'and', 'sentiment', 'analysis', '.']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
nltk.download('stopwords')
stop_word=set(stopwords.words('english'))
words_clean=[w for w in words if w.isalpha() and w not in stop_word]
fdist=FreqDist(words_clean)
print(fdist.most_common(10))
# Out:
# [('language', 2), ('natural', 1), ('processing', 1), ('helps', 1), ('computers', 1), ('understand', 1), ('human', 1), ('applications', 1), ('include', 1), ('chatbots', 1)]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
fdist.plot(20,cumulative=False)
plt.show()

# %%
nltk.download('averaged_perceptron_tagger_eng')
pos_tags=pos_tag(words_clean)
print(pos_tags)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('helps', 'VBZ'), ('computers', 'NNS'), ('understand', 'VBP'), ('human', 'JJ'), ('language', 'NN'), ('applications', 'NNS'), ('include', 'VBP'), ('chatbots', 'NNS'), ('translation', 'JJ'), ('sentiment', 'NN'), ('analysis', 'NN')]

# %%
nouns=[word for word,pos in pos_tags if pos.startswith('NN')]
noun_freq=FreqDist(nouns)
print(noun_freq.most_common(10))
# Out:
# [('language', 2), ('processing', 1), ('computers', 1), ('applications', 1), ('chatbots', 1), ('sentiment', 1), ('analysis', 1)]
